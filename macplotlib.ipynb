# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=1
b=2
a+b
# Out:
# 3

# %%
x=np.array([10,20])
y=np.array([30,40])
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'o')
plt.show()

# %%
x1=np.array([2,13,25,67])
y1=np.array([10,20,85,52])
plt.plot(x1,y1)

# %%
plt.plot(x1,y1,'*')

# %%
plt.plot(x1,y1,'x')

# %%
plt.plot(x1,y1,',')

# %%
plt.plot(x1,y1,'h')

# %%
plt.plot(x1,y1,marker='*')

# %%
plt.plot(x1,y1,marker='*',ms=20,mec="b",mfc="m",linestyle=":",color="r")
